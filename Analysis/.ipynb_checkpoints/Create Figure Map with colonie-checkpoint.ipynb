# %%
# %run libreria.py
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import utm
import pandas as pd
import math
from matplotlib.pyplot import figure
from matplotlib import cm as CM
from matplotlib import mlab as ML
import pymysql

def distancia_genetica_corregida(a, b, distribution, N_mam=269):
    P_A1_a1=1
    P_A2_a2=1
    P_A2_a2_hermano_a2=1
    for alele in distribution:
        P_A1_a1=P_A1_a1*(distribution[alele][a[alele]])
        P_A2_a2=P_A2_a2*(distribution[alele][b[alele]])
        # La probabilidad abajo es: si son iguales, es 1/2 (si vino de la misma columna alelo) + (1/2)*prob_del_alelo si vino de distinta columna, pero si 
        # son distintos son 1/2 * probabilidad de ese alelo. 
        P_A2_a2_hermano_a2=P_A2_a2_hermano_a2*((1/2)*int(a[alele]==b[alele])+(1/2)*distribution[alele][b[alele]])
    P_A1_A2_distinta_mama=P_A1_a1*P_A2_a2
    P_A1_A2_misma_mama=P_A1_a1*P_A2_a2_hermano_a2
    return (1/(1+(N_mam-1)*P_A1_A2_distinta_mama/P_A1_A2_misma_mama))
    

def get_connection():
    return pymysql.connect(host='ec2-18-222-185-142.us-east-2.compute.amazonaws.com',
                             user='root',
                             password='password',
                             db='dbname',
                             charset='utf8mb4',
                             cursorclass=pymysql.cursors.DictCursor)
        
    
import random
d2=0
connection=get_connection()

with connection.cursor() as cursor:
    sql="select * from tasks_abejas where task_params like \"%kuringbai%\" and task_completed>0 and batchname is NULL"
    cursor.execute(sql)
    res=cursor.fetchall()
connection.close()



curvas=pd.DataFrame(res)

curvas["bootstrap"]=[eval(aa)["bootstrap"] for aa in curvas["task_params"]]
curvas["N_mam"]=[eval(aa)["N_mam"] for aa in curvas["task_params"]]
curvas["urban"]=[eval(aa)["urban"] for aa in curvas["task_params"]]
curvas["rural"]=[eval(aa)["rural"] for aa in curvas["task_params"]]
curvas["min_dist"]=[eval(aa).get("min_dist", 1) for aa in curvas["task_params"]]
curvas["lambda"]=[eval(aa)["params"]["lambd"] for aa in curvas["task_params"]]
curvas["exp_mean"]=1/curvas["lambda"]

# %%
list(curvas["task_params"])[-3]
# Out:
# '{"num_abejas":3000, "bootstrap":97, "randomfun":random.expovariate, "params":{"lambd":0.207}, "d2":d2, "min_dist":0.4, "N_mam":76, "urban":True, "rural":True, "weird_coords":True, "year":"kuringbai"}'

# %%
curvas
# Out:
#      batchname  task_completed  task_id       task_name  \
# 0         None      1599045129   143473  montecarlobees
# 1         None      1599035115   143474  montecarlobees
# 2         None      1599030613   143475  montecarlobees
# 3         None      1599043386   143476  montecarlobees
# 4         None      1599046317   143477  montecarlobees
# 5         None      1599042223   143478  montecarlobees
# 6         None      1599038592   143479  montecarlobees
# 7         None      1599039624   143480  montecarlobees
# 8         None      1599044508   143481  montecarlobees
# 9         None      1599030939   143482  montecarlobees
# 10        None      1599036030   143485  montecarlobees
# 11        None      1599052057   143486  montecarlobees
# 12        None      1599045872   143487  montecarlobees
# 13        None      1599044407   143488  montecarlobees
# 14        None      1599045638   143489  montecarlobees
# 15        None      1599043812   143490  montecarlobees
# 16        None      1599032940   143491  montecarlobees
# 17        None      1599031947   143492  montecarlobees
# 18        None      1599051615   143493  montecarlobees
# 19        None      1599037834   143494  montecarlobees
# 20        None      1599036332   143495  montecarlobees
# 21        None      1599046771   143496  montecarlobees
# 22        None      1599032700   143497  montecarlobees
# 23        None      1599050113   143498  montecarlobees
# 24        None      1599035418   143500  montecarlobees
# 25        None      1599048800   143501  montecarlobees
# 26        None      1599046815   143502  montecarlobees
# 27        None      1599040231   143503  montecarlobees
# 28        None      1599036632   143504  montecarlobees
# 29        None      1599043827   143505  montecarlobees
# ...        ...             ...      ...             ...
# 2828      None      1599006404   146443  montecarlobees
# 2829      None      1599043225   146444  montecarlobees
# 2830      None      1599006029   146445  montecarlobees
# 2831      None      1599029418   146446  montecarlobees
# 2832      None      1599012391   146447  montecarlobees
# 2833      None      1599013834   146448  montecarlobees
# 2834      None      1599011137   146449  montecarlobees
# 2835      None      1599013367   146450  montecarlobees
# 2836      None      1599004818   146451  montecarlobees
# 2837      None      1599004507   146452  montecarlobees
# 2838      None      1599007673   146453  montecarlobees
# 2839      None      1599013931   146454  montecarlobees
# 2840      None      1599011710   146455  montecarlobees
# 2841      None      1599009040   146456  montecarlobees
# 2842      None      1599009952   146457  montecarlobees
# 2843      None      1599028956   146458  montecarlobees
# 2844      None      1599006215   146459  montecarlobees
# 2845      None      1599013280   146460  montecarlobees
# 2846      None      1599013931   146461  montecarlobees
# 2847      None      1599048013   146462  montecarlobees
# 2848      None      1599031947   146463  montecarlobees
# 2849      None      1599051967   146464  montecarlobees
# 2850      None      1599005426   146465  montecarlobees
# 2851      None      1599007278   146466  montecarlobees
# 2852      None      1599004524   146467  montecarlobees
# 2853      None      1599006042   146468  montecarlobees
# 2854      None      1599008128   146469  montecarlobees
# 2855      None      1599052559   146470  montecarlobees
# 2856      None      1599005278   146471  montecarlobees
# 2857      None      1599016282   146472  montecarlobees
#
#                                             task_params  \
# 0     {"num_abejas":3000, "bootstrap":0, "randomfun"...
# 1     {"num_abejas":3000, "bootstrap":1, "randomfun"...
# 2     {"num_abejas":3000, "bootstrap":2, "randomfun"...
# 3     {"num_abejas":3000, "bootstrap":3, "randomfun"...
# 4     {"num_abejas":3000, "bootstrap":4, "randomfun"...
# 5     {"num_abejas":3000, "bootstrap":5, "randomfun"...
# 6     {"num_abejas":3000, "bootstrap":6, "randomfun"...
# 7     {"num_abejas":3000, "bootstrap":7, "randomfun"...
# 8     {"num_abejas":3000, "bootstrap":8, "randomfun"...
# 9     {"num_abejas":3000, "bootstrap":9, "randomfun"...
# 10    {"num_abejas":3000, "bootstrap":12, "randomfun...
# 11    {"num_abejas":3000, "bootstrap":13, "randomfun...
# 12    {"num_abejas":3000, "bootstrap":14, "randomfun...
# 13    {"num_abejas":3000, "bootstrap":15, "randomfun...
# 14    {"num_abejas":3000, "bootstrap":16, "randomfun...
# 15    {"num_abejas":3000, "bootstrap":17, "randomfun...
# 16    {"num_abejas":3000, "bootstrap":18, "randomfun...
# 17    {"num_abejas":3000, "bootstrap":19, "randomfun...
# 18    {"num_abejas":3000, "bootstrap":20, "randomfun...
# 19    {"num_abejas":3000, "bootstrap":21, "randomfun...
# 20    {"num_abejas":3000, "bootstrap":22, "randomfun...
# 21    {"num_abejas":3000, "bootstrap":23, "randomfun...
# 22    {"num_abejas":3000, "bootstrap":24, "randomfun...
# 23    {"num_abejas":3000, "bootstrap":25, "randomfun...
# 24    {"num_abejas":3000, "bootstrap":27, "randomfun...
# 25    {"num_abejas":3000, "bootstrap":28, "randomfun...
# 26    {"num_abejas":3000, "bootstrap":29, "randomfun...
# 27    {"num_abejas":3000, "bootstrap":30, "randomfun...
# 28    {"num_abejas":3000, "bootstrap":31, "randomfun...
# 29    {"num_abejas":3000, "bootstrap":32, "randomfun...
# ...                                                 ...
# 2828  {"num_abejas":3000, "bootstrap":70, "randomfun...
# 2829  {"num_abejas":3000, "bootstrap":71, "randomfun...
# 2830  {"num_abejas":3000, "bootstrap":72, "randomfun...
# 2831  {"num_abejas":3000, "bootstrap":73, "randomfun...
# 2832  {"num_abejas":3000, "bootstrap":74, "randomfun...
# 2833  {"num_abejas":3000, "bootstrap":75, "randomfun...
# 2834  {"num_abejas":3000, "bootstrap":76, "randomfun...
# 2835  {"num_abejas":3000, "bootstrap":77, "randomfun...
# 2836  {"num_abejas":3000, "bootstrap":78, "randomfun...
# 2837  {"num_abejas":3000, "bootstrap":79, "randomfun...
# 2838  {"num_abejas":3000, "bootstrap":80, "randomfun...
# 2839  {"num_abejas":3000, "bootstrap":81, "randomfun...
# 2840  {"num_abejas":3000, "bootstrap":82, "randomfun...
# 2841  {"num_abejas":3000, "bootstrap":83, "randomfun...
# 2842  {"num_abejas":3000, "bootstrap":84, "randomfun...
# 2843  {"num_abejas":3000, "bootstrap":85, "randomfun...
# 2844  {"num_abejas":3000, "bootstrap":86, "randomfun...
# 2845  {"num_abejas":3000, "bootstrap":87, "randomfun...
# 2846  {"num_abejas":3000, "bootstrap":88, "randomfun...
# 2847  {"num_abejas":3000, "bootstrap":89, "randomfun...
# 2848  {"num_abejas":3000, "bootstrap":90, "randomfun...
# 2849  {"num_abejas":3000, "bootstrap":91, "randomfun...
# 2850  {"num_abejas":3000, "bootstrap":92, "randomfun...
# 2851  {"num_abejas":3000, "bootstrap":93, "randomfun...
# 2852  {"num_abejas":3000, "bootstrap":94, "randomfun...
# 2853  {"num_abejas":3000, "bootstrap":95, "randomfun...
# 2854  {"num_abejas":3000, "bootstrap":96, "randomfun...
# 2855  {"num_abejas":3000, "bootstrap":97, "randomfun...
# 2856  {"num_abejas":3000, "bootstrap":98, "randomfun...
# 2857  {"num_abejas":3000, "bootstrap":99, "randomfun...
#
#                     task_responsible  bootstrap  N_mam  urban  rural  \
# 0                      18.220.78.232          0     76   True   True
# 1                     18.222.138.152          1     76   True   True
# 2                     18.188.231.240          2     76   True   True
# 3                        3.133.84.90          3     76   True   True
# 4                       13.58.188.25          4     76   True   True
# 5                      3.137.138.139          5     76   True   True
# 6                       3.131.110.96          6     76   True   True
# 7                      13.59.214.173          7     76   True   True
# 8                      18.223.32.184          8     76   True   True
# 9                        3.15.181.72          9     76   True   True
# 10                    18.222.199.111         12     76   True   True
# 11                     3.131.141.179         13     76   True   True
# 12                      3.22.114.227         14     76   True   True
# 13                    18.223.162.206         15     76   True   True
# 14                      3.15.176.152         16     76   True   True
# 15                    18.218.170.145         17     76   True   True
# 16                    18.191.209.157         18     76   True   True
# 17                     18.222.11.221         19     76   True   True
# 18                      3.134.91.103         20     76   True   True
# 19                     18.191.156.37         21     76   True   True
# 20                     3.131.141.156         22     76   True   True
# 21                     18.221.79.160         23     76   True   True
# 22                     18.191.185.20         24     76   True   True
# 23                     18.223.32.126         25     76   True   True
# 24                       3.16.154.55         27     76   True   True
# 25                    18.216.222.122         28     76   True   True
# 26                      3.22.171.158         29     76   True   True
# 27                      13.59.64.174         30     76   True   True
# 28                     18.221.155.32         31     76   True   True
# 29                     18.188.249.73         32     76   True   True
# ...                              ...        ...    ...    ...    ...
# 2828                   52.14.212.219         70     76   True   True
# 2829                    18.189.1.245         71     76   True   True
# 2830                  18.220.208.147         72     76   True   True
# 2831                  18.188.170.170         73     76   True   True
# 2832                    3.22.166.166         74     76   True   True
# 2833                    18.224.94.42         75     76   True   True
# 2834                  18.222.152.121         76     76   True   True
# 2835                  18.222.191.187         77     76   True   True
# 2836                   18.191.213.12         78     76   True   True
# 2837                   3.131.133.174         79     76   True   True
# 2838                     3.17.59.222         80     76   True   True
# 2839                   3.134.113.162         81     76   True   True
# 2840                    18.218.43.27         82     76   True   True
# 2841                    3.131.135.47         83     76   True   True
# 2842                    3.20.237.194         84     76   True   True
# 2843                   18.191.207.86         85     76   True   True
# 2844                   18.222.71.117         86     76   True   True
# 2845                    18.224.72.83         87     76   True   True
# 2846                   3.134.113.162         88     76   True   True
# 2847                    3.131.160.92         89     76   True   True
# 2848                   18.222.11.221         90     76   True   True
# 2849                    18.218.98.70         91     76   True   True
# 2850                     3.16.29.157         92     76   True   True
# 2851                  18.191.248.225         93     76   True   True
# 2852                    3.131.135.54         94     76   True   True
# 2853                      3.17.69.70         95     76   True   True
# 2854                    3.131.82.100         96     76   True   True
# 2855                  18.188.191.157         97     76   True   True
# 2856  2601:184:4700:1820:d146:9be4:f         98     76   True   True
# 2857                    18.222.11.78         99     76   True   True
#
#       min_dist  lambda  exp_mean
# 0          1.0  10.000  0.100000
# 1          1.0  10.000  0.100000
# 2          1.0  10.000  0.100000
# 3          1.0  10.000  0.100000
# 4          1.0  10.000  0.100000
# 5          1.0  10.000  0.100000
# 6          1.0  10.000  0.100000
# 7          1.0  10.000  0.100000
# 8          1.0  10.000  0.100000
# 9          1.0  10.000  0.100000
# 10         1.0  10.000  0.100000
# 11         1.0  10.000  0.100000
# 12         1.0  10.000  0.100000
# 13         1.0  10.000  0.100000
# 14         1.0  10.000  0.100000
# 15         1.0  10.000  0.100000
# 16         1.0  10.000  0.100000
# 17         1.0  10.000  0.100000
# 18         1.0  10.000  0.100000
# 19         1.0  10.000  0.100000
# 20         1.0  10.000  0.100000
# 21         1.0  10.000  0.100000
# 22         1.0  10.000  0.100000
# 23         1.0  10.000  0.100000
# 24         1.0  10.000  0.100000
# 25         1.0  10.000  0.100000
# 26         1.0  10.000  0.100000
# 27         1.0  10.000  0.100000
# 28         1.0  10.000  0.100000
# 29         1.0  10.000  0.100000
# ...        ...     ...       ...
# 2828       0.4   0.207  4.830918
# 2829       0.4   0.207  4.830918
# 2830       0.4   0.207  4.830918
# 2831       0.4   0.207  4.830918
# 2832       0.4   0.207  4.830918
# 2833       0.4   0.207  4.830918
# 2834       0.4   0.207  4.830918
# 2835       0.4   0.207  4.830918
# 2836       0.4   0.207  4.830918
# 2837       0.4   0.207  4.830918
# 2838       0.4   0.207  4.830918
# 2839       0.4   0.207  4.830918
# 2840       0.4   0.207  4.830918
# 2841       0.4   0.207  4.830918
# 2842       0.4   0.207  4.830918
# 2843       0.4   0.207  4.830918
# 2844       0.4   0.207  4.830918
# 2845       0.4   0.207  4.830918
# 2846       0.4   0.207  4.830918
# 2847       0.4   0.207  4.830918
# 2848       0.4   0.207  4.830918
# 2849       0.4   0.207  4.830918
# 2850       0.4   0.207  4.830918
# 2851       0.4   0.207  4.830918
# 2852       0.4   0.207  4.830918
# 2853       0.4   0.207  4.830918
# 2854       0.4   0.207  4.830918
# 2855       0.4   0.207  4.830918
# 2856       0.4   0.207  4.830918
# 2857       0.4   0.207  4.830918
#
# [2858 rows x 13 columns]

# %%
takss=list(set(curvas["task_id"]))

# %%
connection=get_connection()

with connection.cursor() as cursor:
    sql="select distinct task_id, total from familias_abejas_conteo where task_id in ("+", ".join([str(j) for j in takss])+")"
    cursor.execute(sql)
    res=cursor.fetchall()
connection.close()

# %%
finn=curvas.set_index("task_id").join(pd.DataFrame(res).set_index("task_id"))

# %%
len(curvas)
# Out:
# 2858

# %%
len(curvas)
# Out:
# 2858

# %%
plt.figure(figsize=(10, 15))
nmins=sorted(list(set(finn["min_dist"])))
for nmin in nmins:
    fami=finn[(finn.min_dist==nmin)]
    xs=sorted(list(set(fami["exp_mean"])))
    ys=[]
    for x in xs:
        ys.append(fami[fami.exp_mean==x]["total"].mean())
    plt.plot(xs, ys, label=nmin)
    
plt.legend()
plt.ylabel("Number of colonies in area")
plt.xlabel("Mean flight of male bee")
plt.ylim([0,6000])
plt.savefig("colonies_by_flight.pdf")

# %%
set(finn["exp_mean"])
# Out:
# {0.1,
#  0.625,
#  1.1494252873563218,
#  1.6750418760469012,
#  2.1978021978021975,
#  2.7247956403269757,
#  3.2467532467532467,
#  3.773584905660377,
#  4.291845493562231,
#  4.830917874396135}

# %%
i=0
for min_dist in [0.4, 0.6, 1]:
    
    geto=finn[(finn["min_dist"]==min_dist) & ((finn["exp_mean"]==1.1494252873563218))]
    plt.boxplot(geto["total"], positions=[i])
    i+=1
    
plt.xticks([0, 1, 2], ["100m", "200m", "500m"])
plt.xlabel("Distance to trap")
plt.ylabel("Number of colonies")
plt.savefig("distribution_number_colonies600F.pdf")

# %%
# %run /Users/Bernardo/Desktop/bees/libreria.py

# %%
750*3000
# Out:
# 2250000

# %%
coordenadas
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/Bernardo/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3291, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-20-6a5613714f7a>", line 1, in <module>
#     coordenadas
# NameError: name 'coordenadas' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/Bernardo/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2033, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/Bernardo/miniconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1095, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/Bernardo/miniconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/Bernardo/miniconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 347, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/Bernardo/miniconda3/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/Bernardo/miniconda3/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/Bernardo/miniconda3/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/Bernardo/miniconda3/lib/python3.7/inspect.py", line 742, in getmodule
#     os.path.realpath(f)] = module.__name__
# AttributeError: module has no attribute '__name__'
# ---------------------------------------------------------------------------

# %%
starttime=time.time()
    
#get basic information and variables

urban_coords=[]
rural_coords=[]
locations, coordenadas, distance_national_park=get_loc_coords_dnp()
other_coords=["Lindfield", "Gordon", "Stives"]
f=open("distribution_kuringbai.txt", "r")
dict=f.read()
f.close()
distribution=eval(dict)
tot_abejas=480


urban=True
rural=True

xaxis  = [utm.from_latlon(coordenadas[l][0],coordenadas[l][1])[0]  for l in coordenadas]
yaxis =  [utm.from_latlon(coordenadas[l][0],coordenadas[l][1])[1] for l in coordenadas]
medy  =  np.mean(yaxis)
medx  =  np.mean(xaxis)

xaxis  = [to_xy((coordenadas[l][0],coordenadas[l][1]))[0]  for l in coordenadas]
yaxis = [to_xy((coordenadas[l][0],coordenadas[l][1]))[1] for l in coordenadas]
medy2  =  np.mean(yaxis)
medx2  =  np.mean(xaxis)

information={}



for k in coordenadas:
    if k not in urban_coords+rural_coords+other_coords: 
        print(k+" excluded")
    if ((urban==True) and (k in urban_coords)) or ((rural==True) and (k in rural_coords)) or (((rural==True) and (urban==True)) and k in (rural_coords+urban_coords+other_coords)):
        information[k]={}
        information[k]["coordenadas"]=coordenadas[k]
        utm_val=utm.from_latlon(coordenadas[k][0], coordenadas[k][1])
        information[k]["utm_xy_or"]=utm_val
        information[k]["utm_xy"]=((utm_val[0]-medx)/1000, (utm_val[1]-medy)/1000)
        xy_val=to_xy(coordenadas[k])
        information[k]["alt_xy"]=((xy_val[0]-medx2)/1000, (xy_val[1]-medy2)/1000)


list_cor=list(pd.DataFrame(information ).loc["utm_xy"])
list_cor_keys=list(pd.DataFrame(information).transpose().index)
utm_xs=[i[0] for i in list_cor]
utm_ys=[i[1] for i in list_cor]
around=20
xs_max=np.max(utm_xs)+around
xs_min=np.min(utm_xs)-around
ys_max=np.max(utm_ys)+around
ys_min=np.min(utm_ys)-around
# Out:
# Marrickville excluded
# Surry Hills excluded
# Camperdown excluded
# Asheville excluded
# Balgowlah  excluded
# Manley excluded
# Jannali excluded
# Sutherland excluded
# Palmbeach excluded
# Caringbah excluded
# Parramatta excluded
# Strickland excluded

# %%
[(k[0]*1000+medx, k[1]*1000+medy) for k in list_cor]
# Out:
# [(331381.8994091859, 6268948.651472769),
#  (329904.9438023586, 6261716.458296533),
#  (328736.73496348405, 6263160.969183585)]

# %%
xs_max_tr=xs_max*1000+medx
xs_min_tr=xs_min*1000+medx
ys_max_tr=ys_max*1000+medy
ys_min_tr=ys_min*1000+medy

corners=[[xs_max_tr, ys_max_tr], [xs_max_tr, ys_min_tr], [xs_min_tr, ys_min_tr], [xs_min_tr, ys_max_tr]]
ncors=[]
for cor in corners:
    ncors.append(utm.to_latlon(cor[0], cor[1], 56, "H"))
    
ncors.append(ncors[0])

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %%
plt.figure(figsize=(12,12))

# Lambert Conformal Conic map.
m = Basemap(llcrnrlon=150.6,llcrnrlat=-34.591003504203526,
            urcrnrlon=151.7,
            urcrnrlat=-33.391003504203526,
            projection='lcc',lat_1=-33.491003504203526,lat_2=-39.235773685145425,lon_0=150.78201521493236,
            resolution ='h',area_thresh=0.0000005)
# read shapefile.



m.drawcoastlines()
m.drawcountries()
m.drawrivers()

x, y = m([k[1] for k in ncors], [k[0] for k in ncors])
plt.plot(x, y, color="red")

x, y = m([information[p]["coordenadas"][1] for p in information], [information[p]["coordenadas"][0] for p in information])
plt.scatter(x, y)
for xx, yy, s in zip(x, y, list(information.keys())):
    plt.text(xx, yy, s)

kurigngai=["Stives", "Gordon", "Lindfield"]
x, y = m([information[p]["coordenadas"][1] for p in kurigngai], [information[p]["coordenadas"][0] for p in kurigngai])
plt.scatter(x, y, s=1)
plt.savefig("mapColonies.pdf")
# Out:
# /Users/Bernardo/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: MatplotlibDeprecationWarning:
# The dedent function now deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   if __name__ == '__main__':
# /Users/Bernardo/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: MatplotlibDeprecationWarning:
# The dedent function now deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   from ipykernel import kernelapp as app
# /Users/Bernardo/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: MatplotlibDeprecationWarning:
# The dedent function now deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   app.launch_new_instance()

# %%
def gen_distancias_proba(seed, xs_min, ys_min, r1, r2, randomfun, params, num_abejas, pi2,  list_cor, min_dist_2, distribution, medx, medy, d2, year):
	locs=[]
	distancias=[]
	
	rmom1=rsel(distribution)
	rmom2=rsel(distribution)
	letter="H"
	if year=="QL": letter="J"
	
	random.seed(seed+5676)
	land=False
	errors=0
	corrects=0
	while corrects<10:
		loc_familia=(xs_min+random.random()*r1, ys_min+random.random()*r2)
		land=(not consult_loc(loc_familia, medx, medy, d2, letter))
		corrects+=land
	
	if corrects<3 and "bm" in d2:
		errors=0
		locs_familia=[]
		for k in range(3000):
			loc_familia=(xs_min+random.random()*r1, ys_min+random.random()*r2)
			locs_familia.append(loc_familia)
		while (not batch_upload(locs_familia, medx, medy, d2, letter)): 
			locs_familia=[]
			for k in range(3000):
				loc_familia=(xs_min+random.random()*r1, ys_min+random.random()*r2)
				locs_familia.append(loc_familia)
			
	random.seed(seed+5676)
	land=False
	while land==False:
		loc_familia=(xs_min+random.random()*r1, ys_min+random.random()*r2)
		land=(not consult_loc(loc_familia, medx, medy, d2, letter))
		
	
	return locs, loc_familia

# %%
list_cor=list(pd.DataFrame(information ).loc["utm_xy"])
list_cor_keys=list(pd.DataFrame(information).transpose().index)
utm_xs=[i[0] for i in list_cor]
utm_ys=[i[1] for i in list_cor]
xs_max=np.max(utm_xs)+around
xs_min=np.min(utm_xs)-around
ys_max=np.max(utm_ys)+around
ys_min=np.min(utm_ys)-around
print("Min dist "+str(min_dist))
for k in range(len(list_cor)-1):
    for j in range(k+1, len(list_cor)):
        a=euclidean_dist(list_cor[k], list_cor[j])
        if a<min_dist: 
            min_dist=a
print("Min dist "+str(min_dist))

start=time.time()
min_dist_2=min_dist/2
pi2=2*math.pi
r1=(xs_max-xs_min)
r2=(ys_max-ys_min)
# Out:
# Min dist 1
# Min dist 1

# %%
def get_d2():
	connection=get_connection()
	with connection.cursor() as cursor:
		cursor.execute("select * from onwater_results where letter=\"J\"")
		res=cursor.fetchall()
	connection.close()
	d2j={}
	for s in res:
		d2j[(round(s["longitud"], 3), round(s["latitud"], 4))]=s["onwater"]
		
	connection=get_connection()
	with connection.cursor() as cursor:
		cursor.execute("select * from onwater_results where letter=\"H\"")
		res=cursor.fetchall()
	connection.close()
	d2h={}
	for s in res:
		d2h[(round(s["longitud"], 3), round(s["latitud"], 4))]=s["onwater"]
		
	return {"J":d2j, "H":d2h}


d2=get_d2()

# %%
bootstrap=10
seed=100
randomfun=random.expovariate
params={"lambd":10}
num_abejas=3000
year="kuringbai"
locs_familias=[]
for seed in range(2250):

    a, loc= gen_distancias_proba(5676+bootstrap*100000+seed, xs_min=xs_min, ys_min=ys_min, r1=r1, r2=r2, 
                    randomfun=randomfun, params=params,num_abejas=num_abejas, pi2=pi2, list_cor=list_cor, 
                    min_dist_2=min_dist_2, distribution=distribution, medx=medx, medy=medy , d2=d2, year=year)
    locs_familias.append(loc)

# %%
locs_familias_correct=[]
for loc in locs_familias:

    xs_max_tr=loc[0]*1000+medx
    ys_max_tr=loc[1]*1000+medy

    locs_familias_correct.append(utm.to_latlon(xs_max_tr, ys_max_tr, 56, "H"))

# %%
plt.figure(figsize=(12,12))

# Lambert Conformal Conic map.
m = Basemap(llcrnrlon=150.6,llcrnrlat=-34.591003504203526,
            urcrnrlon=151.7,
            urcrnrlat=-33.391003504203526,
            projection='lcc',lat_1=-33.491003504203526,lat_2=-39.235773685145425,lon_0=150.78201521493236,
            resolution ='h',area_thresh=0.0000005)
# read shapefile.



m.drawcoastlines()
m.drawcountries()
m.drawrivers()

x, y = m([k[1] for k in ncors], [k[0] for k in ncors])
plt.plot(x, y, color="red")



x, y = m([k[1] for k in locs_familias_correct], [k[0] for k in locs_familias_correct])
plt.scatter(x, y, color="purple", s=1)


x, y = m([information[p]["coordenadas"][1] for p in information], [information[p]["coordenadas"][0] for p in information])
plt.scatter(x, y)
for xx, yy, s in zip(x, y, list(information.keys())):
    plt.text(xx, yy, s)

kurigngai=["Stives", "Gordon", "Lindfield"]
x, y = m([information[p]["coordenadas"][1] for p in kurigngai], [information[p]["coordenadas"][0] for p in kurigngai])
plt.scatter(x, y, s=1)
plt.savefig("mapColonies.pdf")
# Out:
# /Users/Bernardo/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: MatplotlibDeprecationWarning:
# The dedent function now deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   if __name__ == '__main__':
# /Users/Bernardo/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: MatplotlibDeprecationWarning:
# The dedent function now deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   from ipykernel import kernelapp as app
# /Users/Bernardo/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: MatplotlibDeprecationWarning:
# The dedent function now deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   app.launch_new_instance()

# %%
def gen_proportion_land_square(seed, xs_min, ys_min, r1, r2, randomfun, params, num_abejas, pi2,  list_cor, min_dist_2, distribution, medx, medy, d2, year):
    locs=[]
    distancias=[]

    rmom1=rsel(distribution)
    rmom2=rsel(distribution)
    letter="H"
    if year=="QL": letter="J"

    random.seed(seed+5676)
    land=False
    errors=0
    corrects=0
    while corrects<10:
        loc_familia=(xs_min+random.random()*r1, ys_min+random.random()*r2)
        land=(not consult_loc(loc_familia, medx, medy, d2, letter))
        corrects+=land

    if corrects<3 and "bm" in d2:
        errors=0
        locs_familia=[]
        for k in range(3000):
            loc_familia=(xs_min+random.random()*r1, ys_min+random.random()*r2)
            locs_familia.append(loc_familia)
        while (not batch_upload(locs_familia, medx, medy, d2, letter)): 
            locs_familia=[]
            for k in range(3000):
                loc_familia=(xs_min+random.random()*r1, ys_min+random.random()*r2)
                locs_familia.append(loc_familia)

    random.seed(seed+5676)
    land=False
    landpoints=0
    totiter=10000
    for k in range(totiter):
        loc_familia=(xs_min+random.random()*r1, ys_min+random.random()*r2)
        land=(not consult_loc(loc_familia, medx, medy, d2, letter))
        if land==True: landpoints+=1


    return landpoints/totiter

# %%
gen_proportion_land_square(seed, xs_min, ys_min, r1, r2, randomfun, params, num_abejas, pi2,  list_cor, min_dist_2, distribution, medx, medy, d2, year)
# Out:
# 0.7296

# %%
r1*r2
# Out:
# 2014.2246451317415

# %%
total_land_area = 0.7296*r1*r2

# %%
total_land_area
# Out:
# 1469.5783010881187

# %%
2250*86 / total_land_area
# Out:
# 131.67042535721095

# %%
total_land_area*750/86
# Out:
# 12816.089835070801

# %%
plt.figure(figsize=(10, 10))
nmins=sorted(list(set(finn["min_dist"])))
for nmin in nmins:
    fami=finn[(finn.min_dist==nmin)]
    xs=sorted(list(set(fami["exp_mean"])))
    ys=[]
    for x in xs:
        ys.append(( fami[fami.exp_mean==x]["total"].mean() )*86/total_land_area)
    plt.plot(xs, ys, label=str(int(nmin*1000/2))+"m")
    
plt.legend(title="Catchment area")
plt.ylabel("Minimum number of colonies in Kuringbai")
plt.xlabel("Mean flight of male bee")
plt.plot([-10, 100], [750, 750], color="red")
plt.xlim([0, 5])
#plt.ylim([0,6000])
plt.yscale("log")
plt.savefig("colonies_by_flight.pdf")

# %%
100*

# %%
information.keys()
# Out:
# dict_keys(['Marrickville', 'Surry Hills', 'Camperdown', 'Asheville', 'Balgowlah ', 'Manley', 'Jannali', 'Sutherland', 'Stives', 'Palmbeach', 'Lindfield', 'Gordon', 'Caringbah', 'Parramatta', 'Strickland'])

# %%
ncors
# Out:
# [(-33.491003504203526, 151.53249524349738),
#  (-34.24690062649693, 151.51950041103092),
#  (-34.235773685145425, 150.78201521493236),
#  (-33.48018752375011, 150.80147254288337)]

# %%
sorted(list(set(finn[(finn["min_dist"]==1)]["exp_mean"])))
# Out:
# [0.1,
#  0.275,
#  0.44999999999999996,
#  0.6249999999999999,
#  0.8,
#  0.9749999999999999,
#  1.15,
#  1.325,
#  1.5,
#  1.675,
#  1.8500000000000003,
#  2.025,
#  2.15,
#  2.1999999999999997,
#  2.375,
#  2.55,
#  2.725,
#  2.9,
#  3.0749999999999997,
#  3.25,
#  3.425,
#  3.5999999999999996,
#  3.775,
#  3.9499999999999997,
#  4.124999999999999,
#  4.299999999999999,
#  4.475,
#  4.6499999999999995,
#  4.824999999999999,
#  4.999999999999999,
#  5.174999999999999]
